# %%
import boto3

# %% [markdown]
# ### Packages
# * pip install boto3
# * pip install awscli
# * pip install s3fs

# %%
s3 = boto3.resource('s3')
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# anunay-test
# ashishawszeke
# ashishglue
# ashishzeke21stoct
# aws-emr-resources-043619277480-ap-south-1
# aws-glue-altimatrik
# aws-glue-logs-ashish-singapore
# aws-glue-notebooks-043619277480-ap-southeast-1
# aws-glue-scripts-043619277480-ap-southeast-1
# aws-glue-scripts-043619277480-us-east-1
# aws-glue-temporary-043619277480-ap-southeast-1
# aws-glue-temporary-043619277480-us-east-1
# aws-logs-043619277480-ap-south-1
# aws5thjanbucket
# awsmorningclasszeke
# chin-terraform-bucket
# edyodabucket
# edyodabucketdestination
# elasticbeanstalk-ap-south-1-043619277480
# elasticbeanstalk-ap-southeast-1-043619277480
# elasticbeanstalk-eu-west-2-043619277480
# elasticbeanstalk-us-east-1-043619277480
# epsilonpython
# kms-35461
# kms-36406
# kms-53159
# la-terraform-bucket-63580
# lab-buildpacks-bucket-88891
# lab-droplets-bucket-88891
# lab-ops-manager-bucket-88891
# lab-packages-bucket-88891
# lab-resources-bucket-88891
# max-41354
# max-51855
# max-63733
# nimesh-terraform-bucket
# ...

# %%
my_bucket = s3.Bucket(name = "epsilonpython")

# %%
my_bucket.upload_file("hr_data.csv","input/hr_data_awantik.csv")

# %%
import s3fs
import pandas as pd
fs = s3fs.S3FileSystem(anon=False)

# %%
for obj in my_bucket.objects.all():
    if obj.key == 'input/hr_data_awantik.csv':
        print (obj.key)
# Out:
# input/hr_data_awantik.csv

# %%
with fs.open('epsilonpython/input/hr_data_awantik.csv') as f:
    df = pd.read_csv(f)
    df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 11 columns):
# Unnamed: 0               14999 non-null int64
# satisfaction_level       14999 non-null float64
# last_evaluation          14999 non-null float64
# number_project           14999 non-null int64
# average_montly_hours     14999 non-null int64
# time_spend_company       14999 non-null int64
# Work_accident            14999 non-null int64
# left                     14999 non-null int64
# promotion_last_5years    14999 non-null int64
# department               14999 non-null object
# salary                   14999 non-null object
# dtypes: float64(2), int64(7), object(2)
# memory usage: 1.3+ MB

# %%
with fs.open('epsilonpython/input/hr_data_awantik.csv') as f:
    print (f.read())
# Out:
# b',satisfaction_level,last_evaluation,number_project,average_montly_hours,time_spend_company,Work_accident,left,promotion_last_5years,department,salary\n0,0.38,0.53,2,157,3,0,1,0,sales,low\n1,0.8,0.86,5,262,6,0,1,0,sales,medium\n2,0.11,0.88,7,272,4,0,1,0,sales,medium\n3,0.72,0.87,5,223,5,0,1,0,sales,low\n4,0.37,0.52,2,159,3,0,1,0,sales,low\n5,0.41,0.5,2,153,3,0,1,0,sales,low\n6,0.1,0.77,6,247,4,0,1,0,sales,low\n7,0.92,0.85,5,259,5,0,1,0,sales,low\n8,0.89,1.0,5,224,5,0,1,0,sales,low\n9,0.42,0.53,2,142,3,0,1,0,sales,low\n10,0.45,0.54,2,135,3,0,1,0,sales,low\n11,0.11,0.81,6,305,4,0,1,0,sales,low\n12,0.84,0.92,4,234,5,0,1,0,sales,low\n13,0.41,0.55,2,148,3,0,1,0,sales,low\n14,0.36,0.56,2,137,3,0,1,0,sales,low\n15,0.38,0.54,2,143,3,0,1,0,sales,low\n16,0.45,0.47,2,160,3,0,1,0,sales,low\n17,0.78,0.99,4,255,6,0,1,0,sales,low\n18,0.45,0.51,2,160,3,1,1,1,sales,low\n19,0.76,0.89,5,262,5,0,1,0,sales,low\n20,0.11,0.83,6,282,4,0,1,0,sales,low\n21,0.38,0.55,2,147,3,0,1,0,sales,low\n22,0.09,0.95,6,30
# ...
