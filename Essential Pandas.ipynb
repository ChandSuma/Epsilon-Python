# %%
import pandas as pd

# %%
s1 = pd.Series(data=[1,2,3,4,5],index=['a','b','c','d','e'])

# %%
s1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s2 = pd.Series(data=[11,12,13,14,15],index=['a','b','c','d','f'])

# %%
df = pd.DataFrame({'col1':s1, 'col2':s2})

# %%
df
# Out:
#    col1  col2
# a   1.0  11.0
# b   2.0  12.0
# c   3.0  13.0
# d   4.0  14.0
# e   5.0   NaN
# f   NaN  15.0

# %%
df.columns
# Out:
# Index(['s1', 's2'], dtype='object')

# %%
df
# Out:
#    col1  col2
# a   1.0  11.0
# b   2.0  12.0
# c   3.0  13.0
# d   4.0  14.0
# e   5.0   NaN
# f   NaN  15.0

# %%
hr_data = pd.read_csv('HR_comma_sep.csv.txt')

# %%
hr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
# satisfaction_level       14999 non-null float64
# last_evaluation          14999 non-null float64
# number_project           14999 non-null int64
# average_montly_hours     14999 non-null int64
# time_spend_company       14999 non-null int64
# Work_accident            14999 non-null int64
# left                     14999 non-null int64
# promotion_last_5years    14999 non-null int64
# sales                    14999 non-null object
# salary                   14999 non-null object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
hr_data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
titanic_data = pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/titanic-train.csv.txt', index_col="PassengerId")

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
titanic_data.loc[5:7]
# Out:
#              Survived  Pclass                      Name   Sex   Age  SibSp  \
# PassengerId
# 5                   0       3  Allen, Mr. William Henry  male  35.0      0
# 6                   0       3          Moran, Mr. James  male   NaN      0
# 7                   0       1   McCarthy, Mr. Timothy J  male  54.0      0
#
#              Parch  Ticket     Fare Cabin Embarked
# PassengerId
# 5                0  373450   8.0500   NaN        S
# 6                0  330877   8.4583   NaN        Q
# 7                0   17463  51.8625   E46        S

# %%
hr_data.sample(10)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 12681                0.40             0.49               2
# 8231                 0.18             0.51               5
# 10784                0.13             0.62               5
# 10572                0.66             0.66               3
# 3736                 0.66             0.64               4
# 4366                 0.39             0.64               3
# 33                   0.45             0.55               2
# 486                  0.38             0.49               2
# 5865                 0.17             0.91               6
# 6118                 0.15             0.87               4
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 12681                   128                   3              0     1
# 8231                    159                   6              0     0
# 10784                   268                   3              0     0
# ...

# %%
hr_data.select_dtypes(exclude=['object']).head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years
# 0                   3              0     1                      0
# 1                   6              0     1                      0
# 2                   4              0     1                      0
# 3                   5              0     1                      0
# 4                   3              0     1                      0

# %%
hr_data.select_dtypes(include=['float64']).head()
# Out:
#    satisfaction_level  last_evaluation
# 0                0.38             0.53
# 1                0.80             0.86
# 2                0.11             0.88
# 3                0.72             0.87
# 4                0.37             0.52

# %%
hr_data['last_evaluation'][:5]
# Out:
# 0    0.53
# 1    0.86
# 2    0.88
# 3    0.87
# 4    0.52
# Name: last_evaluation, dtype: float64

# %%
hr_data['last_evaluation']
# Out:
# 0    0.53
# 1    0.86
# 2    0.88
# 3    0.87
# 4    0.52
# Name: last_evaluation, dtype: float64

# %%
df = pd.DataFrame({'col 1':s1, 'col 2':s2})

# %%
df['col 1']
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# f    NaN
# Name: col 1, dtype: float64

# %%
hr_data[5:10]
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 5                0.41             0.50               2                   153
# 6                0.10             0.77               6                   247
# 7                0.92             0.85               5                   259
# 8                0.89             1.00               5                   224
# 9                0.42             0.53               2                   142
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 5                   3              0     1                      0  sales
# 6                   4              0     1                      0  sales
# 7                   5              0     1                      0  sales
# 8                   5              0     1                      0  sales
# 9                   3              0     1                      0  sales
#
#   salary
# 5    low
# 6    low
# 7    low
# 8    low
# 9    low

# %%
hr_data[(hr_data.satisfaction_level > .9) & (hr_data.average_montly_hours < 110)]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2305                 0.91             0.55               6
# 2793                 0.96             0.42               6
# 3173                 0.93             0.77               5
# 4021                 1.00             0.49               3
# 4448                 0.97             0.74               3
# 4691                 0.99             0.44               6
# 4870                 0.99             0.95               4
# 5446                 0.96             0.59               4
# 6884                 0.95             0.38               2
# 8616                 0.99             0.48               3
# 9221                 0.92             0.82               4
# 10038                0.98             0.56               3
# 10116                0.99             0.55               3
# 10243                1.00             0.63               2
# 11962                0.92             0.64               2
# ...

# %%
hr_data.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
cat_data = hr_data.select_dtypes(include=['object'])

# %%
cat_data.salary.value_counts()
# Out:
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64

# %%
cat_data.sales.value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: sales, dtype: int64

# %%
hr_data.rename(columns={'sales':'department'},inplace=True)

# %%
hr_data.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'department', 'salary'],
#       dtype='object')

# %%
hr_data.to_csv('hr_data.csv')

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 123.5+ KB

# %%
titanic_data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic_data[titanic_data.Age == titanic_data.Age.min()].Name.values[0]
# Out:
# 'Thomas, Master. Assad Alexander'

# %%
titanic_data[titanic_data.Age.isna()]
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 6                   0       3                          Moran, Mr. James
# 18                  1       2              Williams, Mr. Charles Eugene
# 20                  1       3                   Masselmani, Mrs. Fatima
# 27                  0       3                   Emir, Mr. Farred Chehab
# 29                  1       3             O'Dwyer, Miss. Ellen "Nellie"
# ...               ...     ...                                       ...
# 860                 0       3                          Razi, Mr. Raihed
# 864                 0       3         Sage, Miss. Dorothy Edith "Dolly"
# 869                 0       3               van Melkebeke, Mr. Philemon
# 879                 0       3                        Laleff, Mr. Kristo
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#                 Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# ...

# %%
titanic_data[titanic_data.Age.notnull()]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 886                 0       3
# 887                 0       2
# 888                 1       1
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
new_titatic_data = titanic_data.dropna(subset=['Age','Cabin'])

# %%
new_titatic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185 entries, 2 to 890
# Data columns (total 11 columns):
# Survived    185 non-null int64
# Pclass      185 non-null int64
# Name        185 non-null object
# Sex         185 non-null object
# Age         185 non-null float64
# SibSp       185 non-null int64
# Parch       185 non-null int64
# Ticket      185 non-null object
# Fare        185 non-null float64
# Cabin       185 non-null object
# Embarked    183 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 17.3+ KB

# %%
titanic_data.Age.median()
# Out:
# 28.0

# %%
titanic_data.fillna({'Age':28, 'Cabin':'SwimmingPool'}, inplace=True)

# %%
hr_data_itr = pd.read_csv('HR_comma_sep.csv.txt', chunksize=5000)

# %%
total_count = 0
for hr_d in hr_data_itr:
    total_count += hr_d.left.size

print (total_count)
# Out:
# 14999

# %%
hr_data_itr = pd.read_csv('HR_comma_sep.csv.txt', nrows=10)

# %%
hr_data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
titanic_data.count()
# Out:
# Survived    891
# Pclass      891
# Name        891
# Sex         891
# Age         891
# SibSp       891
# Parch       891
# Ticket      891
# Fare        891
# Cabin       891
# Embarked    889
# dtype: int64
